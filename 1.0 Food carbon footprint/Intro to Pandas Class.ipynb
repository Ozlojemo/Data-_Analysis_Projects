# %%
# Creating Data Frames and Series 
# Importing and Getting to know your data
# INdexing  
# Filtering and Sorting 
# Grouping 
# Apply : Lambda
# Merge 
# Stats 
# Deleting and Manipulating

# %%
import pandas as pd 
import numpy as np

# %%
# Creating Data Frames and Series

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
data = pd.read_csv(url,sep='\t')

# Importing Excel

# %%
data.shape[1]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
data.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
# Operations 
data.columns = [x.upper() for x in data.columns]
data.head()
# Out:
#    ORDER_ID  QUANTITY                              ITEM_NAME  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   CHOICE_DESCRIPTION ITEM_PRICE
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# Replace Column 
# data.rename(columns={'QUANTITY':'QTY'},inplace=True)
data = data.rename(columns={'CHOICE_DESCRIPTION':'CHOICE'})

# %%
data.describe()
# Out:
#           ORDER_ID          QTY
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
# Operations 
data.QTY.sum()
data
# Out:
# 4972

# %%
# Indexing 
data.loc[0,'ITEM_NAME']
data.iloc[:10,[3,4]]
# Out:
#                                               CHOICE ITEM_PRICE
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
data.loc[:10,['ITEM_NAME','QTY']]
# Out:
#                                 ITEM_NAME  QTY
# 0            Chips and Fresh Tomato Salsa    1
# 1                                    Izze    1
# 2                        Nantucket Nectar    1
# 3   Chips and Tomatillo-Green Chili Salsa    1
# 4                            Chicken Bowl    2
# 5                            Chicken Bowl    1
# 6                           Side of Chips    1
# 7                           Steak Burrito    1
# 8                        Steak Soft Tacos    1
# 9                           Steak Burrito    1
# 10                    Chips and Guacamole    1

# %%
data.iloc[3]
# Out:
# ORDER_ID                                          1
# QTY                                               1
# ITEM_NAME     Chips and Tomatillo-Green Chili Salsa
# CHOICE                                          NaN
# ITEM_PRICE                                   $2.39
# Name: 3, dtype: object

# %%
data.iloc[100:110,2:4]
# Out:
#                ITEM_NAME                                             CHOICE
# 100  Chips and Guacamole                                                NaN
# 101        Steak Burrito  [Tomatillo-Green Chili Salsa (Medium), [Rice, ...
# 102           Steak Bowl  [Tomatillo-Green Chili Salsa (Medium), [Rice, ...
# 103  Chips and Guacamole                                                NaN
# 104       Veggie Burrito  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# 105     Nantucket Nectar                          [Pineapple Orange Banana]
# 106        Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...
# 107          Canned Soda                                       [Dr. Pepper]
# 108        Steak Burrito  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 109  Chips and Guacamole                                                NaN

# %%
# Boolean Indexing 
data[data.QTY>3]
# Out:
#       ORDER_ID  QTY                     ITEM_NAME  \
# 1254       511    4               Chicken Burrito
# 1257       511    4  Chips and Fresh Tomato Salsa
# 1425       577    4                 Bottled Water
# 1880       759    4                 Bottled Water
# 2235       901    4                   Canned Soda
# 2441       970    5                 Bottled Water
# 3598      1443   15  Chips and Fresh Tomato Salsa
# 3599      1443    7                 Bottled Water
# 3602      1443    4               Chicken Burrito
# 3887      1559    8                 Side of Chips
# 3973      1592    4             Canned Soft Drink
# 4152      1660   10                 Bottled Water
# 4489      1786    4           Chips and Guacamole
# 4490      1786    4             Canned Soft Drink
# 4491      1786    4             Canned Soft Drink
#
#                                                  CHOICE ITEM_PRICE
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00
# ...

# %%
# filt = data.QTY>3
# data.loc[filt,'ITEM_NAME']
data.loc[data.QTY>3,['ITEM_NAME','ITEM_PRICE']]
# Out:
#                          ITEM_NAME ITEM_PRICE
# 1254               Chicken Burrito    $35.00
# 1257  Chips and Fresh Tomato Salsa    $11.80
# 1425                 Bottled Water     $6.00
# 1880                 Bottled Water     $6.00
# 2235                   Canned Soda     $4.36
# 2441                 Bottled Water     $7.50
# 3598  Chips and Fresh Tomato Salsa    $44.25
# 3599                 Bottled Water    $10.50
# 3602               Chicken Burrito    $35.00
# 3887                 Side of Chips    $13.52
# 3973             Canned Soft Drink     $5.00
# 4152                 Bottled Water    $15.00
# 4489           Chips and Guacamole    $17.80
# 4490             Canned Soft Drink     $5.00
# 4491             Canned Soft Drink     $5.00

# %%
# Is in operation
CHOICES = ['Chicken Burrito','Bottled Water']
data.ITEM_NAME.isin(CHOICES)
data[data.ITEM_NAME.isin(CHOICES) & data.QTY<2]
# Out:
#       ORDER_ID  QTY                              ITEM_NAME  \
# 0            1    1           Chips and Fresh Tomato Salsa
# 1            1    1                                   Izze
# 2            1    1                       Nantucket Nectar
# 3            1    1  Chips and Tomatillo-Green Chili Salsa
# 4            2    2                           Chicken Bowl
# ...        ...  ...                                    ...
# 4617      1833    1                          Steak Burrito
# 4618      1833    1                          Steak Burrito
# 4619      1834    1                     Chicken Salad Bowl
# 4620      1834    1                     Chicken Salad Bowl
# 4621      1834    1                     Chicken Salad Bowl
#
#                                                  CHOICE ITEM_PRICE
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# ...

# %%
data[data.ITEM_NAME.isin(CHOICES) | data.QTY>=2] # To be investigate
# Out:
# Empty DataFrame
# Columns: [ORDER_ID, QTY, ITEM_NAME, CHOICE, ITEM_PRICE]
# Index: []

# %%
df = data.copy()

# %%
df.head()
# Out:
#    ORDER_ID  QTY                              ITEM_NAME  \
# 0         1    1           Chips and Fresh Tomato Salsa
# 1         1    1                                   Izze
# 2         1    1                       Nantucket Nectar
# 3         1    1  Chips and Tomatillo-Green Chili Salsa
# 4         2    2                           Chicken Bowl
#
#                                               CHOICE ITEM_PRICE
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# MISSINGNESS 
# 1. Delete 
# 2. Fill - Mean, Mode, Median
# 3. Impute - KNN , SMOTE 
df.dropna(how='any')
# Out:
#       ORDER_ID  QTY           ITEM_NAME  \
# 1            1    1                Izze
# 2            1    1    Nantucket Nectar
# 4            2    2        Chicken Bowl
# 5            3    1        Chicken Bowl
# 7            4    1       Steak Burrito
# ...        ...  ...                 ...
# 4617      1833    1       Steak Burrito
# 4618      1833    1       Steak Burrito
# 4619      1834    1  Chicken Salad Bowl
# 4620      1834    1  Chicken Salad Bowl
# 4621      1834    1  Chicken Salad Bowl
#
#                                                  CHOICE ITEM_PRICE
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...                                                 ...        ...
# ...

# %%
df.sort_values('QTY',ascending=False)
# Out:
#       ORDER_ID  QTY                              ITEM_NAME  \
# 3598      1443   15           Chips and Fresh Tomato Salsa
# 4152      1660   10                          Bottled Water
# 3887      1559    8                          Side of Chips
# 3599      1443    7                          Bottled Water
# 2441       970    5                          Bottled Water
# ...        ...  ...                                    ...
# 1592       645    1                           Chicken Bowl
# 1593       645    1  Chips and Tomatillo Green Chili Salsa
# 1594       646    1                          Carnitas Bowl
# 1595       646    1                        Chicken Burrito
# 4621      1834    1                     Chicken Salad Bowl
#
#                                                  CHOICE ITEM_PRICE
# 3598                                                NaN    $44.25
# 4152                                                NaN    $15.00
# ...

# %%
# Group by 
df.groupby('ITEM_NAME').sum()
# Out:
#                                        ORDER_ID  QTY
# ITEM_NAME
# 6 Pack Soft Drink                         52322   55
# Barbacoa Bowl                             53972   66
# Barbacoa Burrito                          74718   91
# Barbacoa Crispy Tacos                      5613   12
# Barbacoa Salad Bowl                        9708   10
# Barbacoa Soft Tacos                       18725   25
# Bottled Water                            175944  211
# Bowl                                        472    4
# Burrito                                    1550    6
# Canned Soda                               76396  126
# Canned Soft Drink                        304753  351
# Carnitas Bowl                             62742   71
# Carnitas Burrito                          51652   60
# Carnitas Crispy Tacos                      5868    8
# Carnitas Salad                             1500    1
# Carnitas Salad Bowl                        6693    6
# ...

# %%
# Lambda Function
function_name = lambda x: x*10

# %%
df['QTY'].apply(lambda x: x/10)
# Out:
# 0       0.1
# 1       0.1
# 2       0.1
# 3       0.1
# 4       0.2
#        ...
# 4617    0.1
# 4618    0.1
# 4619    0.1
# 4620    0.1
# 4621    0.1
# Name: QTY, Length: 4622, dtype: float64

# %%
# price = '$11.25'
# float(price[1:])
df.ITEM_PRICE = df.ITEM_PRICE.apply(lambda y: float(y[1:]))
df.describe()
# Out:
#           ORDER_ID          QTY   ITEM_PRICE
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %%
# Out:
# 11.25
